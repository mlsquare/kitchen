# %% [markdown]
# # Implementation Documentation

# %% [markdown]
# Sections:
# 1. Configs
# 2. Data
# 3. Outputs
# 4. Scripts

# %% [markdown]
# ## 1. Configs

# %% [markdown]
# ### Example config

# %%
import json
dataset_name = 'auto'

with open('../Configs/'+dataset_name+'.json') as config_file:
        config = json.load(config_file)

# %%
print(json.dumps(config, indent = 4, sort_keys = False))
# Out:
# {
#     "name": "adult",
#     "type": "classification",
#     "primary_paths": "adult_local_paths_1000.csv",
#     "secondary_paths": "adult_local_paths_per_instance_1000.csv",
#     "data_with_headers": "adult_headers.csv",
#     "filtered_data_with_headers": "adult_filtered.csv",
#     "perturbed_data": "adult_perturbed.csv",
#     "local_bins": "adult_local_bin_labels_1000.csv",
#     "perturbed_paths": "adult_perturbed_paths_1000.csv",
#     "perturbed_local_bins": "adult_perturbed_bin_labels_1000.csv",
#     "tree_depths": "adult_local_depths_1000.csv",
#     "tree_widths": "adult_tree_widths.csv",
#     "leaf_nodes": "adult_leaf_nodes.csv",
#     "variable_importance": "adult_variable_importance_1000.csv",
#     "num_features": 14,
#     "target_col": 15,
#     "path_regex": "([0-9]{1,2})([A-Z]+)([01])",
#     "primary_weight": 0.25,
#     "secondary_weight": 0.01,
#     "frame_folder": "local_dt_info_adult",
#     "size": 30162,
#     "sample": 1000,
#     "classes": [
#         "<=50K",
#         ">50K"
#     ],
#     "columns": [
#         "age",
#         "workclass",
#         "fnlwgt",
#         "education",
#         "education-num",
#         "marital-status",
#         "occupation",
#         "relationship",
#         "race",
#         "sex",
#         "capital-gain",
#         "capital-loss",
#         "hours-per-week",
#         "native-country",
#         "target"
#     ],
#     "factors": "adult_dataset_factors.csv",
#     "data_numeric": "adult_numeric.csv"
# }

# %% [markdown]
# ### Config details

# %% [markdown]
# - name: name of the dataset
# - type: type of task (accepted values: classification, regression)
# - primary_paths: name of csv of primary paths
# - secondary_paths: name of csv of secondary paths
# - data_with_headers: name of csv of data with header
# - filtered_data_with_headers: name of csv of filtered data (no NA) with header
# - perturbed_data: name of csv of perturbed data
# - local_bins: name of csv of local bins
# - perturbed_paths: name of csv with original and perturbed paths
# - perturbed_local_bins: name of csv with bins corresponding to the file perturbed_paths
# - tree_depths: name of csv with tree depth data
# - tree_widths: name of csv with maximum tree width data
# - leaf_nodes: name of csv with leaf node data
# - variable importance: name of csv containing variable importance for local trees
# - num_features: number of features in the dataset
# - target_col: target column
# - path_regex: regex used to convert each node of the path from string to tuple form
# - primary weight: weight of primary instance in it's own local tree
# - secondary weight: weight of secondary instance in the local tree of another instance
# - frame_folder: name of folder containing frames for local trees
# - size: size of filtered dataset
# - sample: number of rows of dataset used
# - classes: class labels
# - columns: names of dataset columns
# - factors: name of csv with factor name to numerical index mapping for each factor (optional: only if dataset has categorical data)
# - data_numeric: name of csv of data in numeric format (optional: only if dataset has categorical data)

# %% [markdown]
# ## 2. Data

# %%
import pandas as pd

# %% [markdown]
# ### a. Data with header

# %%
pd.read_csv("../Data/"+config['data_with_headers'])
# Out:
#        Age          Workclass  Fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital-gain  Capital-loss  Hours-per-week  Native-country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        Target
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ### b. Filtered data with header

# %% [markdown]
# ? values removed

# %%
pd.read_csv("../Data/"+config['filtered_data_with_headers'])
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30157   27            Private  257302   Assoc-acdm             12
# 30158   40            Private  154374      HS-grad              9
# 30159   58            Private  151910      HS-grad              9
# 30160   22            Private  201490      HS-grad              9
# 30161   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 30157   Married-civ-spouse        Tech-support            Wife   White
# 30158   Married-civ-spouse   Machine-op-inspct         Husband   White
# 30159              Widowed        Adm-clerical       Unmarried   White
# 30160        Never-married        Adm-clerical       Own-child   White
# 30161   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 30157   Female             0             0              38   United-States
# 30158     Male             0             0              40   United-States
# 30159   Female             0             0              40   United-States
# 30160     Male             0             0              20   United-States
# 30161   Female         15024             0              40   United-States
#
#        target
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 30157   <=50K
# 30158    >50K
# 30159   <=50K
# 30160   <=50K
# 30161    >50K
#
# [30162 rows x 15 columns]

# %% [markdown]
# ### c. Perturbed data

# %% [markdown]
# Column 14 has the original target class labels and column 15 has the new predicted class labels after perturbation

# %%
pd.read_csv("../Data/"+config['perturbed_data'])
# Out:
#          0                  1         2           3     4  \
# 0     27.0            Private       0.0        11th  18.0
# 1     83.0        Federal-gov  102036.0        11th  21.0
# 2      0.0       Self-emp-inc       0.0        12th  18.0
# 3    143.0   Self-emp-not-inc       0.0     7th-8th  15.0
# 4     48.0        Without-pay  202380.0     5th-6th   7.0
# ..     ...                ...       ...         ...   ...
# 995   66.0          State-gov       0.0     7th-8th  15.0
# 996    3.0        Without-pay  826889.0   Bachelors   0.0
# 997   69.0   Self-emp-not-inc  325515.0     HS-grad   8.0
# 998   41.0          Local-gov  195258.0        10th  10.0
# 999   32.0        Federal-gov  385395.0        11th   1.0
#
#                           5                   6                7  \
# 0             Never-married     Priv-house-serv        Own-child
# 1     Married-spouse-absent    Transport-moving          Husband
# 2                  Divorced     Protective-serv   Other-relative
# 3                 Separated   Machine-op-inspct   Other-relative
# 4        Married-civ-spouse     Protective-serv        Own-child
# ..                      ...                 ...              ...
# 995                Divorced     Priv-house-serv        Unmarried
# 996                Divorced   Handlers-cleaners             Wife
# 997                Divorced     Farming-fishing          Husband
# 998      Married-civ-spouse     Protective-serv          Husband
# 999       Married-AF-spouse     Exec-managerial        Unmarried
#
#                        8        9        10      11     12              13  \
# 0     Asian-Pac-Islander     Male   26846.0   260.0   36.0       Guatemala
# 1     Asian-Pac-Islander     Male   17371.0  1063.0   48.0         Ecuador
# 2                  White     Male  136862.0     0.0  173.0       Guatemala
# 3     Amer-Indian-Eskimo   Female   14175.0   351.0  112.0           India
# 4                  White   Female    8591.0  1404.0   69.0        Portugal
# ..                   ...      ...       ...     ...    ...             ...
# 995                Black   Female   24498.0     0.0   17.0     El-Salvador
# 996   Amer-Indian-Eskimo   Female   88760.0     0.0   94.0            Peru
# 997                White     Male    9542.0     0.0   80.0       Guatemala
# 998                White     Male       0.0     0.0   40.0   United-States
# 999   Amer-Indian-Eskimo     Male   24281.0     0.0   64.0        Columbia
#
#          14      15
# 0     <=50K    >50K
# 1     <=50K    >50K
# 2     <=50K    >50K
# 3     <=50K    >50K
# 4     <=50K    >50K
# ..      ...     ...
# 995   <=50K    >50K
# 996   <=50K    >50K
# 997   <=50K    >50K
# 998    >50K   <=50K
# 999   <=50K    >50K
#
# [1000 rows x 16 columns]

# %% [markdown]
# ### d. Numeric Data (Optional)

# %% [markdown]
# Data obtained by applying the factor mapping to a dataset.

# %%
df = None
if 'data_numeric' in config:
    df = pd.read_csv("../Data/"+config['data_numeric'])
df
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          8   77516         10             13               5
# 1       50          7   83311         10             13               3
# 2       38          5  215646         12              9               1
# 3       53          5  234721          2              7               3
# 4       28          5  338409         10             13               3
# ...    ...        ...     ...        ...            ...             ...
# 30157   27          5  257302          8             12               3
# 30158   40          5  154374         12              9               3
# 30159   58          5  151910         12              9               7
# 30160   22          5  201490         12              9               5
# 30161   52          6  287927         12              9               3
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               2             2     5    2          2174             0
# 1               5             1     5    2             0             0
# 2               7             2     5    2             0             0
# 3               7             1     3    2             0             0
# 4              11             6     3    1             0             0
# ...           ...           ...   ...  ...           ...           ...
# 30157          14             6     5    1             0             0
# 30158           8             1     5    2             0             0
# 30159           2             5     5    1             0             0
# 30160           2             4     5    2             0             0
# 30161           5             6     5    1         15024             0
#
#        hours-per-week  native-country  target
# 0                  40              40       1
# 1                  13              40       1
# 2                  40              40       1
# 3                  40              40       1
# 4                  40               6       1
# ...               ...             ...     ...
# 30157              38              40       1
# 30158              40              40       2
# 30159              40              40       1
# 30160              20              40       1
# 30161              40              40       2
#
# [30162 rows x 15 columns]

# %% [markdown]
# ## 3. Outputs

# %% [markdown]
# ### a. Primary paths

# %%
pd.read_csv("../Outputs/"+config['primary_paths'])
# Out:
#                           paths
# 0                  7A0,14B0,8A0
# 1                     11C0,13D0
# 2                       6E0,4F0
# 3              7G0,12H0,2I0,7G0
# 4                  7J0,4K0,13L0
# ..                          ...
# 995               6M0,11BH0,2I0
# 996          11C0,4F0,7I0,13BK0
# 997                 4F0,8E1,7M0
# 998         6Q1,7F1,1EL1,13AEL1
# 999  7A0,4AN0,11FX0,7A0,8E0,2I0
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### b. Secondary paths

# %%
pd.read_csv("../Outputs/"+config['secondary_paths'], index_col = 0)
# Out:
#                     X1                                      X2  \
# 1        11BC0,8T0,7A0                            4L1,6C0,10A0
# 2    11BM0,7A0,4E0,2U0                            4L1,6C0,10A0
# 3             1BZ0,2C0  11Y0,2H0,4E0,7K0,13W1,3FV0,11FW0,13FX0
# 4          8C0,4N0,7U0            13FI0,12GY0,2H0,14B0,4N0,9C0
# 5        11BC0,8T0,7A0                     11IZ0,4L1,6AC1,3JK0
# ..                 ...                                     ...
# 96                 NaN                                     NaN
# 97                 NaN                                     NaN
# 98                 NaN                                     NaN
# 99                 NaN                                     NaN
# 100                NaN                                     NaN
#
#                                X3                         X4  \
# 1                    6C0,2U0,3BH0     8I1,1AX1,7U1,12AY0,2C1
# 2                    6C0,2U0,3BH0               7U0,2C0,1DI0
# 3    13FI0,12GY0,2C0,14B0,4N0,9C0      7A0,4E0,14B0,3DV1,7A0
# 4               7J1,6AC1,3JQ1,4P1             13CP1,3EM0,2C1
# 5        7U0,11FW0,2C0,12NW0,1CO0  7V0,4P0,9C0,7V1,1EP0,3EQ0
# ..                            ...                        ...
# 96                            NaN                        NaN
# 97                            NaN                        NaN
# 98                            NaN                        NaN
# 99                            NaN                        NaN
# 100                           NaN                        NaN
#
#                              X5              X6                           X7  \
# 1                  7U0,14B0,8Q0   7U0,4N0,13AS0  11Y0,13Z1,7U0,4A0,6C0,13AB0
# 2                   7C1,8T0,4P0   11BK0,7Q0,8I0  11Y0,13Z1,7U0,4A0,6C0,13AB0
# 3                       8A0,4L0    7C1,8C0,1DM0                     7K1,1DH0
# 4    8I1,7Q0,7Q1,1EW1,2C1,13CP0  13CP1,3EM0,2C1                      7Q0,7Q0
# 5                   6C0,2C0,7Q0   7U0,4N0,13AS0                2C0,6C0,13AH0
# ..                          ...             ...                          ...
# 96                          NaN             NaN                          NaN
# 97                          NaN             NaN                          NaN
# 98                          NaN             NaN                          NaN
# 99                          NaN             NaN                          NaN
# 100                         NaN             NaN                          NaN
#
#                     X8                             X9  \
# 1    7Q0,1BD0,3FS1,2C0                    7J1,1D1,4U0
# 2            13AO1,4N0                 11ET0,8T0,1CU0
# 3         6I0,7V1,1EP1                    7J1,1D1,4U0
# 4           6I0,12ABM0                 11ET0,8T0,1CU0
# 5              8Q0,2C0  7A0,3IO1,3IP0,11IQ0,13IR0,7A0
# ..                 ...                            ...
# 96                 NaN                            NaN
# 97                 NaN                            NaN
# 98                 NaN                            NaN
# 99                 NaN                            NaN
# 100                NaN                            NaN
#
#                               X10  ...                      X991  \
# 1    11Y0,13Z1,7V0,4P0,6AC0,13AB0  ...                 11BC0,1Z0
# 2                    8I1,1AX0,4L0  ...                 11BC0,1Z0
# 3    11Y0,13Z1,7V0,4P0,6AC0,13AB0  ...  13FL0,11ET0,4E0,2U1,1FK1
# 4                    8I1,1AX0,4L0  ...         4L1,8A1,1DU0,1FK1
# 5                4P0,6AC1,7C1,7C1  ...              8I1,7V1,1DY0
# ..                            ...  ...                       ...
# 96                            NaN  ...                       NaN
# 97                            NaN  ...                       NaN
# 98                            NaN  ...                       NaN
# 99                            NaN  ...                       NaN
# 100                           NaN  ...                       NaN
#
#                     X992                        X993               X994  \
# 1          7J1,8Q0,12AN0                     7A0,2A1  7U0,12AM0,2C0,7U0
# 2       7V1,6I1,14B1,8C1              7K0,1EZ0,11DO0       7J1,6C0,1DS0
# 3    11ET0,8C0,1CU1,3EV0                     7A0,2A1     13CP1,3EM0,2T1
# 4          7J1,8Q0,12AN0              7K0,1EZ0,11DO0      7J1,6AC1,1FG1
# 5       7V1,6I1,14B1,8C1  7J1,3GP0,8I1,3GR0,7J0,1AV1  7U0,12AM0,2C0,7U0
# ..                   ...                         ...                ...
# 96                   NaN                         NaN                NaN
# 97                   NaN                         NaN                NaN
# 98                   NaN                         NaN                NaN
# 99                   NaN                         NaN                NaN
# 100                  NaN                         NaN                NaN
#
#                             X995           X996                      X997  \
# 1    11Y0,13Z1,7U0,4N0,6C0,13AB0      11Y0,13Z0  7U0,14B0,8I1,7U0,4N0,2C0
# 2                       1BZ0,2A0   7U0,7U1,1CP1         7H0,12AM0,2C0,7H0
# 3               7K0,8I1,7K1,1DH0      11BC0,1Z0                   4K1,6I1
# 4    11Y0,13Z1,7U0,4N0,6C0,13AB0  8T0,4E1,13CP0                   8A0,4H0
# 5                       1BZ0,2A0        8I1,7A1  7U0,14B0,8I1,7U0,4N0,2C0
# ..                           ...            ...                       ...
# 96                           NaN            NaN                       NaN
# 97                           NaN            NaN                       NaN
# 98                           NaN            NaN                       NaN
# 99                           NaN            NaN                       NaN
# 100                          NaN            NaN                       NaN
#
#                   X998                        X999  \
# 1                  7K0                   6I0,11BX0
# 2     7L0,1EZ1,7L1,2C1           7V1,6AC1,14B1,8I1
# 3                  7K0  6AC1,4E1,1CR1,3CS0,2C0,7K0
# 4     7L0,1EZ1,7L1,2C1                   6I0,11BX0
# 5    7R0,1BD0,3FS1,2C0           7V1,6AC1,14B1,8I1
# ..                 ...                         ...
# 96                 NaN                         NaN
# 97                 NaN                         NaN
# 98                 NaN                         NaN
# 99                 NaN                         NaN
# 100                NaN                         NaN
#
#                              X1000
# 1                    11BK0,7J0,8I0
# 2                    11FJ0,2A0,7T0
# 3                    11BK0,7J0,8I0
# 4                    11FJ0,2A0,7T0
# 5    7L0,3IO1,3IP0,11IQ0,13IR0,7L0
# ..                             ...
# 96                             NaN
# 97                             NaN
# 98                             NaN
# 99                             NaN
# 100                            NaN
#
# [100 rows x 1000 columns]

# %% [markdown]
# ### c. Local bins

# %%
pd.read_csv("../Outputs/"+config['local_bins'])
# Out:
#      Unnamed: 0 values.global_bins.
# 0             A                 (2)
# 1            AB                  49
# 2           ABC             92578.5
# 3           ABD             30968.5
# 4           ABE                (21)
# ...         ...                 ...
# 1648         XY            341681.5
# 1649         XZ              276705
# 1650          Y                4225
# 1651         YZ               96714
# 1652          Z                37.5
#
# [1653 rows x 2 columns]

# %% [markdown]
# ### d. Perturbed paths

# %%
pd.read_csv("../Outputs/"+config['perturbed_paths'])
# Out:
#                        original            perturbed
# 0                  7A0,14B0,8A0            7P0,14AD1
# 1                     11C0,13D0                 11C1
# 2                       6E0,4F0              6E0,4Q1
# 3              7G0,12H0,2I0,7G0     7G0,12H0,2I0,7G0
# 4                  7J0,4K0,13L0   7J0,4I0,13L1,13BN1
# ..                          ...                  ...
# 995               6M0,11BH0,2I0            6E0,11BH1
# 996          11C0,4F0,7I0,13BK0                 11C1
# 997                 4F0,8E1,7M0      4F0,8E1,7I1,2I1
# 998         6Q1,7F1,1EL1,13AEL1  6Q1,7J1,1EL1,13AEL1
# 999  7A0,4AN0,11FX0,7A0,8E0,2I0       7AP0,4A0,11FX1
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### e. Perturbed local bins

# %% [markdown]
# Applicable to large datasets for which one script produces primary+secondary paths and another produces primary+perturbed paths. A separate set of local bins i.e. perturbed_local_bins is maintained for the latter.

# %%
pd.read_csv("../Outputs/"+config['perturbed_local_bins'])
# Out:
#     Unnamed: 0 values.global_bins.
# 0            A                 (2)
# 1           AB              1824.5
# 2          ABC                60.5
# 3          ABD               40943
# 4          ABE                  60
# ..         ...                 ...
# 582         XY            271185.5
# 583         XZ                98.5
# 584          Y                (27)
# 585         YZ              159137
# 586          Z                4071
#
# [587 rows x 2 columns]

# %% [markdown]
# ### f. Tree depths

# %%
pd.read_csv("../Outputs/"+config['tree_depths'])
# Out:
#      x
# 0    7
# 1    7
# 2    6
# 3    9
# 4    5
# ..  ..
# 995  6
# 996  5
# 997  5
# 998  5
# 999  7
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### g. Tree widths

# %% [markdown]
# Maximum tree width in each local tree and the depth at which the maximum width occurs.

# %%
pd.read_csv("../Outputs/"+config['tree_widths'])
# Out:
#      width  at-depth
# 0        4         2
# 1        8         5
# 2        4         2
# 3        8         3
# 4        8         3
# ..     ...       ...
# 995      6         3
# 996      4         3
# 997      2         1
# 998      6         3
# 999      6         6
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### h. Leaf nodes

# %% [markdown]
# Number of leaf nodes in each local tree and the list of leaf nodes.

# %%
pd.read_csv("../Outputs/"+config['leaf_nodes'])
# Out:
#      num_leaves                                             leaves
# 0            13  [5, 6, 8, 14, 19, 30, 37, 63, 72, 124, 125, 14...
# 1            15  [3, 4, 41, 43, 44, 47, 80, 84, 85, 90, 91, 92,...
# 2            10           [4, 5, 12, 15, 26, 28, 29, 55, 108, 109]
# 3            16  [9, 10, 11, 12, 15, 16, 26, 27, 28, 29, 35, 68...
# 4            11        [8, 10, 11, 12, 13, 15, 18, 28, 29, 38, 39]
# ..          ...                                                ...
# 995          13  [5, 8, 13, 14, 18, 19, 24, 31, 50, 60, 61, 102...
# 996           8                     [3, 9, 10, 16, 22, 23, 34, 35]
# 997           6                             [3, 4, 10, 23, 44, 45]
# 998          10            [4, 10, 12, 13, 14, 23, 30, 31, 44, 45]
# 999          12     [5, 6, 7, 9, 34, 64, 66, 67, 70, 71, 130, 131]
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### i. Variable importance

# %% [markdown]
# Matrix of variable importance of each feature in a local tree. NaN if value is not available.

# %%
pd.read_csv("../Outputs/"+config['variable_importance'])
# Out:
#            age  workclass    fnlwgt  education  education-num  marital-status  \
# 0    11.411598   3.416068  0.507198   9.673437       3.329528        3.906292
# 1     8.129641   7.071155  7.541180   8.206366       0.310662        1.795567
# 2     6.987798   8.229027  5.301051  14.677562       8.686763       11.032258
# 3     7.489889   6.433319  1.180088  10.792876       9.636746        6.875077
# 4     5.178472   1.923206  4.260837   6.287867       4.949216        1.350000
# ..         ...        ...       ...        ...            ...             ...
# 995   7.988674   6.071879  1.529524   6.754286       3.000000       11.931648
# 996   4.119048   3.435923  2.738024   4.431548       1.620536        2.976190
# 997  10.807314  11.631777  7.250000  16.694835       9.601538             NaN
# 998  20.825110  10.753428  2.904762  23.128379       5.638824       27.647192
# 999   7.666667   0.641975  0.444444   3.097680       0.888889        0.444444
#
#      occupation  relationship      race       sex  capital-gain  capital-loss  \
# 0     17.319525      4.109172       NaN       NaN           NaN           NaN
# 1      7.054799      1.006509       NaN       NaN      6.736842           NaN
# 2     13.039755      0.507937  0.649351  0.507937      1.240966           NaN
# 3     10.791003      9.423401  0.438336  4.247207      1.521372      2.955690
# 4      6.039838      2.700000       NaN       NaN           NaN           NaN
# ..          ...           ...       ...       ...           ...           ...
# 995    8.543184           NaN       NaN  2.727234      2.371030           NaN
# 996    6.841805      0.270089       NaN       NaN      6.600833           NaN
# 997   14.997314      3.235165       NaN  1.653529           NaN      2.743297
# 998   23.531889      2.186759       NaN  8.624887      0.335601           NaN
# 999    9.814710      0.928306       NaN       NaN      1.803995           NaN
#
#      hours-per-week  native-country
# 0          2.853881        4.452669
# 1          7.347508        0.481055
# 2          5.281920        1.240966
# 3          2.054706             NaN
# 4          3.667484        1.306047
# ..              ...             ...
# 995        4.668138             NaN
# 996        0.475904             NaN
# 997       10.502454        1.371648
# 998        2.713124        4.373518
# 999             NaN             NaN
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### j. Factors (Optional)

# %% [markdown]
# - Mapping of factors to numeric index.
# - The number in row 0 indicates the column number of the feature in the dataset (numbered from 1).
# - The numeric index used for each level in R is indicated by row number. <br>
# - For example, the mapping for marital-status is: <br>
# {1: Divorced, 2: Married-AF-spouse, ..., 7: Widowed}

# %%
df = None
if 'factors' in config:
    df = pd.read_csv("../Outputs/"+config['factors'])
df
# Out:
#             workclass      education          marital-status  \
# 0                   2              4                       6
# 1                   ?           10th                Divorced
# 2         Federal-gov           11th       Married-AF-spouse
# 3           Local-gov           12th      Married-civ-spouse
# 4        Never-worked        1st-4th   Married-spouse-absent
# 5             Private        5th-6th           Never-married
# 6        Self-emp-inc        7th-8th               Separated
# 7    Self-emp-not-inc            9th                 Widowed
# 8           State-gov     Assoc-acdm                     NaN
# 9         Without-pay      Assoc-voc                     NaN
# 10                NaN      Bachelors                     NaN
# 11                NaN      Doctorate                     NaN
# 12                NaN        HS-grad                     NaN
# 13                NaN        Masters                     NaN
# 14                NaN      Preschool                     NaN
# 15                NaN    Prof-school                     NaN
# 16                NaN   Some-college                     NaN
# 17                NaN            NaN                     NaN
# 18                NaN            NaN                     NaN
# 19                NaN            NaN                     NaN
# 20                NaN            NaN                     NaN
# 21                NaN            NaN                     NaN
# 22                NaN            NaN                     NaN
# 23                NaN            NaN                     NaN
# 24                NaN            NaN                     NaN
# 25                NaN            NaN                     NaN
# 26                NaN            NaN                     NaN
# 27                NaN            NaN                     NaN
# 28                NaN            NaN                     NaN
# 29                NaN            NaN                     NaN
# 30                NaN            NaN                     NaN
# 31                NaN            NaN                     NaN
# 32                NaN            NaN                     NaN
# 33                NaN            NaN                     NaN
# 34                NaN            NaN                     NaN
# 35                NaN            NaN                     NaN
# 36                NaN            NaN                     NaN
# 37                NaN            NaN                     NaN
# 38                NaN            NaN                     NaN
# 39                NaN            NaN                     NaN
# 40                NaN            NaN                     NaN
# 41                NaN            NaN                     NaN
# 42                NaN            NaN                     NaN
#
#             occupation     relationship                 race      sex  \
# 0                    7                8                    9       10
# 1                    ?          Husband   Amer-Indian-Eskimo   Female
# 2         Adm-clerical    Not-in-family   Asian-Pac-Islander     Male
# 3         Armed-Forces   Other-relative                Black      NaN
# 4         Craft-repair        Own-child                Other      NaN
# 5      Exec-managerial        Unmarried                White      NaN
# 6      Farming-fishing             Wife                  NaN      NaN
# 7    Handlers-cleaners              NaN                  NaN      NaN
# 8    Machine-op-inspct              NaN                  NaN      NaN
# 9        Other-service              NaN                  NaN      NaN
# 10     Priv-house-serv              NaN                  NaN      NaN
# 11      Prof-specialty              NaN                  NaN      NaN
# 12     Protective-serv              NaN                  NaN      NaN
# 13               Sales              NaN                  NaN      NaN
# 14        Tech-support              NaN                  NaN      NaN
# 15    Transport-moving              NaN                  NaN      NaN
# 16                 NaN              NaN                  NaN      NaN
# 17                 NaN              NaN                  NaN      NaN
# 18                 NaN              NaN                  NaN      NaN
# 19                 NaN              NaN                  NaN      NaN
# 20                 NaN              NaN                  NaN      NaN
# 21                 NaN              NaN                  NaN      NaN
# 22                 NaN              NaN                  NaN      NaN
# 23                 NaN              NaN                  NaN      NaN
# 24                 NaN              NaN                  NaN      NaN
# 25                 NaN              NaN                  NaN      NaN
# 26                 NaN              NaN                  NaN      NaN
# 27                 NaN              NaN                  NaN      NaN
# 28                 NaN              NaN                  NaN      NaN
# 29                 NaN              NaN                  NaN      NaN
# 30                 NaN              NaN                  NaN      NaN
# 31                 NaN              NaN                  NaN      NaN
# 32                 NaN              NaN                  NaN      NaN
# 33                 NaN              NaN                  NaN      NaN
# 34                 NaN              NaN                  NaN      NaN
# 35                 NaN              NaN                  NaN      NaN
# 36                 NaN              NaN                  NaN      NaN
# 37                 NaN              NaN                  NaN      NaN
# 38                 NaN              NaN                  NaN      NaN
# 39                 NaN              NaN                  NaN      NaN
# 40                 NaN              NaN                  NaN      NaN
# 41                 NaN              NaN                  NaN      NaN
# 42                 NaN              NaN                  NaN      NaN
#
#                  native-country  target
# 0                            14      15
# 1                             ?   <=50K
# 2                      Cambodia    >50K
# 3                        Canada     NaN
# 4                         China     NaN
# 5                      Columbia     NaN
# 6                          Cuba     NaN
# 7            Dominican-Republic     NaN
# 8                       Ecuador     NaN
# 9                   El-Salvador     NaN
# 10                      England     NaN
# 11                       France     NaN
# 12                      Germany     NaN
# 13                       Greece     NaN
# 14                    Guatemala     NaN
# 15                        Haiti     NaN
# 16           Holand-Netherlands     NaN
# 17                     Honduras     NaN
# 18                         Hong     NaN
# 19                      Hungary     NaN
# 20                        India     NaN
# 21                         Iran     NaN
# 22                      Ireland     NaN
# 23                        Italy     NaN
# 24                      Jamaica     NaN
# 25                        Japan     NaN
# 26                         Laos     NaN
# 27                       Mexico     NaN
# 28                    Nicaragua     NaN
# 29   Outlying-US(Guam-USVI-etc)     NaN
# 30                         Peru     NaN
# 31                  Philippines     NaN
# 32                       Poland     NaN
# 33                     Portugal     NaN
# 34                  Puerto-Rico     NaN
# 35                     Scotland     NaN
# 36                        South     NaN
# 37                       Taiwan     NaN
# 38                     Thailand     NaN
# 39              Trinadad&Tobago     NaN
# 40                United-States     NaN
# 41                      Vietnam     NaN
# 42                   Yugoslavia     NaN

# %% [markdown]
# ## 4. Scripts

# %% [markdown]
# ### Python script usage

# %% [markdown]
# python3 script.py --dataset DATASET

# %% [markdown]
# ### Datasets supported

# %% [markdown]
# - iris
# - adult
# - auto
